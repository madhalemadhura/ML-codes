# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/loan.csv")
df.head(5)
df.tail(10)
# Out:
#        Age    Education  Person Income  Employee Experience  Loan Amount  \
# 44990   31       Master         136832                    9        12319
# 44991   24  High School          37786                    0        13500
# 44992   23     Bachelor          40925                    0         9000
# 44993   27  High School          35512                    4         5000
# 44994   24    Associate          31924                    2        12229
# 44995   27    Associate          47971                    6        15000
# 44996   37    Associate          65800                   17         9000
# 44997   33    Associate          56942                    7         2771
# 44998   29     Bachelor          33164                    4        12000
# 44999   24  High School          51609                    1         6665
#
#        Credit History  Credit Score Previous Loan  Loan Status
# 44990               7           722            No            1
# ...
